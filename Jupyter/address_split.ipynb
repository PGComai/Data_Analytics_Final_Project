# %%
import pandas as pd

df = pd.read_csv('BC_Final_clean_again.csv')
df.head()
# Out:
#    User_ID   Age                  Address  Book_Rating        ISBN  \
# 0    11400  49.0  ottawa, ontario, canada            9  0786868716
# 1    11400  49.0  ottawa, ontario, canada            6  0151008116
# 2    11400  49.0  ottawa, ontario, canada            7  0312195516
# 3    11400  49.0  ottawa, ontario, canada            7  0316789089
# 4    11400  49.0  ottawa, ontario, canada            8  0743418174
#
#                                           Book_Title      Book_Author  \
# 0                 The Five People You Meet in Heaven      Mitch Albom
# 1                                         Life of Pi      Yann Martel
# 2                The Red Tent (Bestselling Backlist)    Anita Diamant
# 3  The Pilot's Wife : A Novel Tag: Author of the ...     Anita Shreve
# 4                                        Good in Bed  Jennifer Weiner
#
#    Year_Of_Publication                Publisher
# 0                 2003                 Hyperion
# ...

# %%
df.shape
# Out:
# (263008, 9)

# %%
df.describe()
# Out:
#              User_ID            Age    Book_Rating  Year_Of_Publication
# count  263008.000000  263008.000000  263008.000000        263008.000000
# mean   138092.380338      36.742361       7.740362          1995.761353
# std     78826.116405      12.162215       1.813123             7.553983
# min        19.000000      10.000000       1.000000          1376.000000
# 25%     72163.000000      28.000000       7.000000          1993.000000
# 50%    135265.000000      35.000000       8.000000          1998.000000
# 75%    206365.500000      45.000000       9.000000          2001.000000
# max    278852.000000      85.000000      10.000000          2050.000000

# %%
df.dtypes
# Out:
# User_ID                  int64
# Age                    float64
# Address                 object
# Book_Rating              int64
# ISBN                    object
# Book_Title              object
# Book_Author             object
# Year_Of_Publication      int64
# Publisher               object
# dtype: object

# %%
df[['City', 'State', 'Country']] = df['Address'].str.split(',', n=2, expand=True)
df.head()
# Out:
#    User_ID   Age                  Address  Book_Rating        ISBN  \
# 0    11400  49.0  ottawa, ontario, canada            9  0786868716
# 1    11400  49.0  ottawa, ontario, canada            6  0151008116
# 2    11400  49.0  ottawa, ontario, canada            7  0312195516
# 3    11400  49.0  ottawa, ontario, canada            7  0316789089
# 4    11400  49.0  ottawa, ontario, canada            8  0743418174
#
#                                           Book_Title      Book_Author  \
# 0                 The Five People You Meet in Heaven      Mitch Albom
# 1                                         Life of Pi      Yann Martel
# 2                The Red Tent (Bestselling Backlist)    Anita Diamant
# 3  The Pilot's Wife : A Novel Tag: Author of the ...     Anita Shreve
# 4                                        Good in Bed  Jennifer Weiner
#
#    Year_Of_Publication                Publisher    City     State  Country
# ...

# %%
df.to_csv('data_address_split.csv', index=False)
