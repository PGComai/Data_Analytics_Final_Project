# %%
import pandas as pd

df = pd.read_csv('../CSV/Twice_Cleaned_Country.csv')
df.head()
# Out:
#     User_ID   Age  Book_Rating        ISBN             Book_Author  \
# 0  161968.0  25.0          1.0   394580567          Robert Fulghum
# 1   56235.0  80.0          2.0    60740450  Gabriel Garcia Marquez
# 2  207976.0  65.0          9.0   812925238      Robert S. McNamara
# 3  108856.0  60.0          4.0   671019937              John Walsh
# 4   57304.0  46.0          8.0  1570717257            Tony Parsons
#
#    Year_Of_Publication             Publisher                   Country
# 0               1989.0      Random House Inc               Afghanistan
# 1               2004.0             Perennial               Afghanistan
# 2               1995.0      Random House Inc               Afghanistan
# 3               1998.0                 Atria  United States of America
# 4               2001.0  Sourcebooks Landmark                    Canada

# %%
titles = df.groupby('ISBN')
titles.count()
# Out:
#             User_ID  Age  Book_Rating  Book_Author  Year_Of_Publication  \
# ISBN
# 000104799X        2    2            2            2                    2
# 000160418X        1    1            1            1                    1
# 000215871X        1    1            1            1                    1
# 000221766X        1    1            1            1                    1
# 000222674X        1    1            1            1                    1
# ...             ...  ...          ...          ...                  ...
# B0001FZGBC        1    1            1            1                    1
# B0001FZGPI        1    1            1            1                    1
# B0001FZGRQ        1    1            1            1                    1
# B0001GMSV2        2    2            2            2                    2
# B000234N3A        1    1            1            1                    1
#
#             Publisher  Country
# ISBN
# 000104799X          2        2
# 000160418X          1        1
# 000215871X          1        1
# 000221766X          1        1
# 000222674X          1        1
# ...               ...      ...
# B0001FZGBC          1        1
# B0001FZGPI          1        1
# B0001FZGRQ          1        1
# B0001GMSV2          2        2
# B000234N3A          1        1
#
# [115480 rows x 7 columns]

# %%
top_books = titles.Book_Rating.median()

# %%
top_books.to_json('../Web/static/js/median_ratings.json')

# %%
book_ages = titles.Age.median()
book_ages
# Out:
# ISBN
# 000104799X    59.0
# 000160418X    61.0
# 000215871X    42.0
# 000221766X    60.0
# 000222674X    51.0
#               ...
# B0001FZGBC    50.0
# B0001FZGPI    26.0
# B0001FZGRQ    46.0
# B0001GMSV2    28.5
# B000234N3A    34.0
# Name: Age, Length: 115480, dtype: float64

# %%
book_ages.to_json('../Web/static/js/median_ages.json')

# %%
book_info_df = top_books.to_frame(name='median_rating').reset_index()
book_info_df.head()
# Out:
#          ISBN  median_rating
# 0  000104799X            7.5
# 1  000160418X            7.0
# 2  000215871X            7.0
# 3  000221766X            8.0
# 4  000222674X            9.0

# %%
book_ages_df = book_ages.to_frame(name='median_reader_age').reset_index()
book_ages_df.head()
# Out:
#          ISBN  median_reader_age
# 0  000104799X               59.0
# 1  000160418X               61.0
# 2  000215871X               42.0
# 3  000221766X               60.0
# 4  000222674X               51.0

# %%
book_info_df = book_info_df.merge(book_ages_df)

# %%
book_instances = titles.User_ID.sum()
book_instances
# Out:
# ISBN
# 000104799X    194800.0
# 000160418X     10067.0
# 000215871X    130085.0
# 000221766X    265031.0
# 000222674X    170184.0
#                 ...
# B0001FZGBC     58551.0
# B0001FZGPI    222207.0
# B0001FZGRQ    192093.0
# B0001GMSV2    203966.0
# B000234N3A    100906.0
# Name: User_ID, Length: 115480, dtype: float64

# %%
book_inst_df = book_instances.to_frame(name='users_read').reset_index()
book_info_df = book_info_df.merge(book_inst_df)
book_info_df.head()
# Out:
#          ISBN  median_rating  median_reader_age  users_read
# 0  000104799X            7.5               59.0    194800.0
# 1  000160418X            7.0               61.0     10067.0
# 2  000215871X            7.0               42.0    130085.0
# 3  000221766X            8.0               60.0    265031.0
# 4  000222674X            9.0               51.0    170184.0

# %%
authors = titles.Book_Author.first()
authors
# Out:
# ISBN
# 000104799X        Ellis Peters
# 000160418X       Carolyn Keene
# 000215871X        Rory MacLean
# 000221766X    Thomas Armstrong
# 000222674X      Winston Graham
#                     ...
# B0001FZGBC     Jennifer Weiner
# B0001FZGPI             Amy Tan
# B0001FZGRQ        Jean M. Auel
# B0001GMSV2     Rosie O'Donnell
# B000234N3A        David Rakoff
# Name: Book_Author, Length: 115480, dtype: object

# %%
countries = df.groupby('Country')
countries.count()
# Out:
#                      User_ID  Age  Book_Rating  ISBN  Book_Author  \
# Country
# Afghanistan                3    3            3     3            3
# Algeria                    1    1            1     1            1
# Andorra                    8    8            8     8            8
# Angola                     1    1            1     1            1
# Antigua and Barbuda        2    2            2     2            2
# ...                      ...  ...          ...   ...          ...
# Venezuela                  8    8            8     8            8
# Vietnam                   10   10           10    10           10
# Yugoslavia                 3    3            3     3            3
# Zambia                     1    1            1     1            1
# Zimbabwe                   1    1            1     1            1
#
#                      Year_Of_Publication  Publisher
# Country
# Afghanistan                            3          3
# Algeria                                1          1
# Andorra                                8          8
# Angola                                 1          1
# Antigua and Barbuda                    2          2
# ...                                  ...        ...
# Venezuela                              8          8
# Vietnam                               10         10
# Yugoslavia                             3          3
# Zambia                                 1          1
# Zimbabwe                               1          1
#
# [129 rows x 7 columns]

# %%
test = df.loc[df['ISBN'] == '971880107'].groupby('Country')
test.count()
# Out:
#                           User_ID  Age  Book_Rating  ISBN  Book_Author  \
# Country
# Australia                      51   51           51    51           51
# Austria                         7    7            7     7            7
# Belgium                         3    3            3     3            3
# Brazil                          2    2            2     2            2
# Canada                         39   39           39    39           39
# China                           2    2            2     2            2
# Egypt                           1    1            1     1            1
# Finland                         2    2            2     2            2
# France                          2    2            2     2            2
# Germany                        23   23           23    23           23
# India                           3    3            3     3            3
# Indonesia                       3    3            3     3            3
# Iran                            1    1            1     1            1
# Ireland                         2    2            2     2            2
# Italy                           1    1            1     1            1
# Japan                           1    1            1     1            1
# Kenya                           1    1            1     1            1
# Kuwait                          1    1            1     1            1
# Macedonia                       1    1            1     1            1
# Malaysia                        3    3            3     3            3
# Mauritius                       1    1            1     1            1
# Mexico                          1    1            1     1            1
# Nepal                           1    1            1     1            1
# Netherlands                     2    2            2     2            2
# New Zealand                    12   12           12    12           12
# Nigeria                         1    1            1     1            1
# Peru                            1    1            1     1            1
# Philippines                     3    3            3     3            3
# Poland                          3    3            3     3            3
# Portugal                        3    3            3     3            3
# Romania                         4    4            4     4            4
# Singapore                       3    3            3     3            3
# South Africa                    1    1            1     1            1
# Spain                           7    7            7     7            7
# Switzerland                     2    2            2     2            2
# Turkey                          1    1            1     1            1
# United Kingdom                 36   36           36    36           36
# United States of America      236  236          236   236          236
# Yugoslavia                      1    1            1     1            1
#
#                           Year_Of_Publication  Publisher
# Country
# Australia                                  51         51
# Austria                                     7          7
# Belgium                                     3          3
# Brazil                                      2          2
# Canada                                     39         39
# China                                       2          2
# Egypt                                       1          1
# Finland                                     2          2
# France                                      2          2
# Germany                                    23         23
# India                                       3          3
# Indonesia                                   3          3
# Iran                                        1          1
# Ireland                                     2          2
# Italy                                       1          1
# Japan                                       1          1
# Kenya                                       1          1
# Kuwait                                      1          1
# Macedonia                                   1          1
# Malaysia                                    3          3
# Mauritius                                   1          1
# Mexico                                      1          1
# Nepal                                       1          1
# Netherlands                                 2          2
# New Zealand                                12         12
# Nigeria                                     1          1
# Peru                                        1          1
# Philippines                                 3          3
# Poland                                      3          3
# Portugal                                    3          3
# Romania                                     4          4
# Singapore                                   3          3
# South Africa                                1          1
# Spain                                       7          7
# Switzerland                                 2          2
# Turkey                                      1          1
# United Kingdom                             36         36
# United States of America                  236        236
# Yugoslavia                                  1          1
